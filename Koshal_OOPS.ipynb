# %% [markdown]
# <a href="https://colab.research.google.com/github/Koshal26/OOPS_Python/blob/main/Koshal_OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# OOPS Theoretical

# %%
# Q.1 - What is Object-Oriented Programming (OOP)?
# Ans.1 - A programming paradigm based on "objects" that contain both data (attributes) and code (methods).

# Q.2 - What is a class in OOP?
# Ans.2 - A blueprint or template used to define the structure and behavior of objects.

# Q.3 - What is an object in OOP?
# Ans.3 - An instance of a class; a concrete entity created based on the class definition.

# Q.4 - What is the difference between abstraction and encapsulation?
# Ans.4 - Abstraction hides internal complexity, while encapsulation bundles data and methods to restrict direct access.

# Q.5 - What are dunder methods in Python?
# Ans.5 - Special methods with double underscores (e.g., __init__) that define how objects behave with built-in operations.

# Q.6 - Explain the concept of inheritance in OOP.
# Ans.6 - A mechanism where a child class derives properties and behaviors from a parent class to promote reuse.

# Q.7 - What is polymorphism in OOP?
# Ans.7 - The ability of different objects to respond to the same method call in their own specific way.

# Q.8 - How is encapsulation achieved in Python?
# Ans.8 - By using naming conventions like single (_) or double (__) underscores to signal private or protected members.

# Q.9 - What is a constructor in Python?
# Ans.9 - The __init__ method, which is automatically executed to initialize an object's attributes upon creation.

# Q.10 - What are class and static methods in Python?
# Ans.10 - Class methods (@classmethod) access class state, while static methods (@staticmethod) do not access class or instance state.

# Q.11 - What is method overloading in Python?
# Ans.11 - Defining multiple behaviors for a method name; in Python, this is usually handled via default or variable arguments.

# Q.12 - What is method overriding in OOP?
# Ans.12 - When a child class provides a new implementation for a method that is already defined in its parent class.

# Q.13 - What is a property decorator in Python?
# Ans.13 - The @property decorator allows a method to be accessed like an attribute (getter/setter functionality).

# Q.14 - Why is polymorphism important in OOP?
# Ans.14 - It provides flexibility by allowing a single interface to be used for a general class of actions.

# Q.15 - What is an abstract class in Python?
# Ans.15 - A class that cannot be instantiated and exists only to define a common interface for its subclasses.

# Q.16 - What are the advantages of OOP?
# Ans.16 - Improved code reusability, modularity, easier maintenance, and effective data security.

# Q.17 - What is the difference between a class variable and an instance variable?
# Ans.17 - Class variables are shared by all instances; instance variables are unique to each specific object.

# Q.18 - What is multiple inheritance in Python?
# Ans.18 - A feature where a single class can inherit attributes and methods from more than one parent class.

# Q.19 - Explain the purpose of '__str__' and '__repr__' methods in Python.
# Ans.19 - __str__ provides a readable string for users; __repr__ provides an unambiguous string for developers/debugging.

# Q.20 - What is the significance of the 'super()' function in Python?
# Ans.20 - It allows you to call methods from a parent class without naming the parent explicitly.

# Q.21 - What is the significance of the __del__ method in Python?
# Ans.21 - It acts as a destructor, called when an object is about to be destroyed or garbage collected.

# Q.22 - What is the difference between @staticmethod and @classmethod in Python?
# Ans.22 - @classmethod receives the class as an implicit first argument; @staticmethod receives no implicit arguments.

# Q.23 - How does polymorphism work in Python with inheritance?
# Ans.23 - Subclasses override parent methods so the same call executes the subclass-specific version.

# Q.24 - What is method chaining in Python OOP?
# Ans.24 - Calling multiple methods in a single statement by having each method return 'self'.

# Q.25 - What is the purpose of the __call__ method in Python?
# Ans.25 - It allows an instance of a class to be called and executed like a standard function.

# %% [markdown]
# OOPS Practical

# %%
#Q1. - Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".
#Ans -
class Animal:
    def speak(self): print("Animal makes a sound")

class Dog(Animal):
    def speak(self): print("Bark!")

Dog().speak()
# Out:
# Bark!

# %%
#Q2. - Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
#Ans -
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self): pass

class Circle(Shape):
    def area(self, r): return 3.14 * r * r

class Rectangle(Shape):
    def area(self, l, w): return l * w

print(Rectangle().area(5, 4))
# Out:
# 20

# %%
#Q3. - Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
#Ans -
class Vehicle:
    def __init__(self, type): self.type = type

class Car(Vehicle): pass

class ElectricCar(Car):
    def __init__(self, type, battery):
        super().__init__(type)
        self.battery = battery

ec = ElectricCar("Sedan", "100kWh")
print(ec.type, ec.battery)
# Out:
# Sedan 100kWh

# %%
#Q4. - Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
#Ans -
class Bird:
    def fly(self): print("Bird flies")

class Sparrow(Bird):
    def fly(self): print("Sparrow flies fast")

class Penguin(Bird):
    def fly(self): print("Penguins cannot fly")

for bird in [Sparrow(), Penguin()]: bird.fly()
# Out:
# Sparrow flies fast
# Penguins cannot fly

# %%
#Q5. - Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
#Ans -
class BankAccount:
    def __init__(self, balance): self.__balance = balance
    def deposit(self, amt): self.__balance += amt
    def withdraw(self, amt): self.__balance -= amt
    def check_balance(self): return self.__balance

account = BankAccount(1000)
print(account.check_balance())
# Out:
# 1000

# %%
#Q6. - Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().
#Ans -
class Instrument:
    def play(self): pass

class Guitar(Instrument):
    def play(self): print("Strumming guitar")

class Piano(Instrument):
    def play(self): print("Playing piano keys")

def start_music(instrument): instrument.play()
start_music(Guitar())
# Out:
# Strumming guitar

# %%
#Q7. - Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.
#Ans -
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b): return a + b
    @staticmethod
    def subtract_numbers(a, b): return a - b

print(MathOperations.add_numbers(10, 5), MathOperations.subtract_numbers(10, 5))
# Out:
# 15 5

# %%
#Q8. - Implement a class Person with a class method to count the total number of persons created.
#Ans -
class Person:
    count = 0
    def __init__(self): Person.count += 1
    @classmethod
    def get_count(cls): return cls.count

p1, p2 = Person(), Person()
print(Person.get_count())
# Out:
# 2

# %%
#Q9. - Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
#Ans -
class Fraction:
    def __init__(self, n, d): self.n, self.d = n, d
    def __str__(self): return f"{self.n}/{self.d}"

print(Fraction(3, 4))
# Out:
# 3/4

# %%
#Q10. - Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
#Ans -
class Vector:
    def __init__(self, x, y): self.x, self.y = x, y
    def __add__(self, other): return Vector(self.x + other.x, self.y + other.y)
    def __repr__(self): return f"Vector({self.x}, {self.y})"

print(Vector(1, 2) + Vector(3, 4))
# Out:
# Vector(4, 6)

# %%
#Q11. - Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
#Ans -
class Person:
    def __init__(self, name, age): self.name, self.age = name, age
    def greet(self): print(f"Hello, my name is {self.name} and I am {self.age} years old.")

Person("Alice", 25).greet()
# Out:
# Hello, my name is Alice and I am 25 years old.

# %%
#Q12. - Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
#Ans -
class Student:
    def __init__(self, name, grades): self.name, self.grades = name, grades
    def average_grade(self): return sum(self.grades) / len(self.grades)

print(Student("Bob", [85, 90, 95]).average_grade())
# Out:
# 90.0

# %%
#Q13. - Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
#Ans -
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width
    def area(self):
        return self.length * self.width

rect = Rectangle()
rect.set_dimensions(5, 10)
print(rect.area())
# Out:
# 50

# %%
#Q14. - Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
#Ans -
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus=500):
        return super().calculate_salary(hours, rate) + bonus

print(Manager().calculate_salary(40, 20))
# Out:
# 1300

# %%
#Q15. - Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
#Ans -
class Product:
    def __init__(self, name, price, quantity):
        self.name, self.price, self.quantity = name, price, quantity
    def total_price(self):
        return self.price * self.quantity

print(Product("Laptop", 1000, 2).total_price())
# Out:
# 2000

# %%
#Q16. - Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
#Ans -
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self): pass

class Cow(Animal):
    def sound(self): print("Moo")

class Sheep(Animal):
    def sound(self): print("Baa")

Cow().sound()
# Out:
# Moo

# %%
#Q17. - Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
#Ans -
class Book:
    def __init__(self, title, author, year):
        self.title, self.author, self.year = title, author, year
    def get_book_info(self):
        return f"{self.title} by {self.author} ({self.year})"

print(Book("1984", "George Orwell", 1949).get_book_info())
# Out:
# 1984 by George Orwell (1949)

# %%
#Q18. - Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
#Ans -
class House:
    def __init__(self, address, price):
        self.address, self.price = address, price

class Mansion(House):
    def __init__(self, address, price, rooms):
        super().__init__(address, price)
        self.rooms = rooms

m = Mansion("123 Luxury Ln", 5000000, 15)
print(m.address, m.rooms)
# Out:
# 123 Luxury Ln 15
